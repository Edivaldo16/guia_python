# %% [markdown]
# # Entrada e Saidas de Dados

# %%
x=input("Entrada de Dados \t")

print("X = ",x)
print(type(x)) #String é um Tipo primitivo 

y=int(input("\n Digite aqui \t")) #Conversão do Tipo de Dados

print(y)
print(type(y))

z=float(input("\n digite aqui \n"))

print(z)
print(type(z))

print("\n")

p = 20 == 20

print(p)
print(type(p))

print("a soma vale",int(x)+z+y) #forma 1 de printar
print("a soma vale {}".format(y+z))#format 2 de printar
print(f'Formatado {x} + {y} + {z} ') #Forma 3 de printar RECOMENDADO
print('%i - %.2f'%(y,z))

# %% [markdown]
# # Modulos ou Bibliotecas

# %% [markdown]
# # Manipulação de Texto

# %%
string = "Python % é uma linguagem de programação de alto nível"

x=int(input("Digite a posição"))

print(string[0:x]) # Mais Comum

print(string[0:10:2]) #Pulando 

print(len(string)) #Tamanho da String

print(string.count(' ')) #Quantidade de a

print(string.count("a",0,10)) #Quantida de a em um intervalo determinado

print(string.find("%")) #Encontra a posicao de %

print("Python" in string)

string.replace("Python","Pitão")

print(string.upper())

print(string.lower())

print(string.capitalize())

print(string.title()) 

print(string.strip()) #Remove os espaços no inicio e fim

print(string.rstrip())

print(string.lstrip())

print(string.split()) #Gera listas de Palavras atraves dos espaços

print("-".join(string))

# %% [markdown]
# # Funções Embutidas

# %% [markdown]
# https://docs.python.org/pt-br/3/library/functions.html

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Operadores

# %% [markdown]
# ## Operadores Matematicos

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Operadores Relacionais

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Operadores de Atribuição

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Operadores Lógicos

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Estruturas de Dados

# %% [markdown]
# ## Listas

# %% [markdown]
# https://docs.python.org/pt-br/3/tutorial/introduction.html#lists

# %% [markdown]
# ## Tuplas

# %% [markdown]
# https://docs.python.org/pt-br/3/tutorial/datastructures.html#tuples-and-sequences

# %% [markdown]
# ## Dicionarios

# %% [markdown]
# https://docs.python.org/pt-br/3/tutorial/datastructures.html#dictionaries

# %% [markdown]
# # Estruturas Condicionais

# %% [markdown]
# https://docs.python.org/pt-br/3/tutorial/controlflow.html

# %%
x=int(input("Digite a sua idade"))

if(x>=18 and x<60): #Se
  print("liberado")

elif(x>60): #Senão
  print("Excedeu o limite de idade")

else: #Caso contrario
  print("não liberado")

# %%
# IF\ELSE\ELIF SEM PARENTESES

x=int(input("Digite a sua idade"))

if x>=18 and x<60: #Se
  print("liberado")

elif x>60: #Senão
  print("Excedeu o limite de idade")

else: #Caso contrario
  print("não liberado")

# %% [markdown]
# # Estruturas de Repetição

# %% [markdown]
# ## For

# %%
#LOOP FOR

tupla = (1,2,4)

for i in tupla: #Usando tupla 
  print(i)
print("\n")

lista = [1,2,3,65]

for i in lista: #Usando lista
  print(i)
print('\n')

for i in range(0,10,2): #Usando metodo range(inicio,fim - 1, progressão)
  print(i)

# %%
#LOOP FOR COM STRING

for i in "1 2 3 4 5 6 7 oito nove dez":
  print(i,i == ' ')

# %%
#LOOP FOR DENTRO DO FOR

for i in range(0,3):
  for a in range(0,3):
    print(i*a)

# %%
lista = [[1,2,3],[10,20,30],[100,200,300]]

print(lista[0],lista[1],lista[2])

for i in range(0,3):
  for a in lista[i]:
    print(a)

for z in lista:
  print(z)

# %% [markdown]
# ## While

# %%
i = 0

while i < 7:
  print("Execução",i)
  i=i+1

# %%
#WHILE COM ELSE 

i=0

while i != 6:
  i+=1
  print(i)

else:
  print("Saiu do while com o i=",i)

# %% [markdown]
# ## Continue, Pass e Break

# %%
#Diferença do Continue e Pass


for i in range(0,10):
  if i == 7:
    print("I=",i)
    #continue
    pass # O comando pass simplesmente passa 
    print("Passou")

for a in 'iadisaodkameixiami':
  if a == "k":
    continue # O comando tira a execuçao do comando onde ele esta inserido
    print("---")
  print(".")

# %%
# BREAK

lista = []

for i in 'exmimxeieixZkiwmiwmxiwimimexi':
  if i == 'Z':
    break #O break para a execução da estrutura mais externa nesse caso o for
  lista.append(i)

print(lista)

# %% [markdown]
# # Funções e Métodos

# %% [markdown]
# ## Funções

# %% [markdown]
# https://docs.python.org/pt-br/3/tutorial/controlflow.html#defining-functions

# %%
#Criando e chamando função

def fuc():
  print("Função criada")

fuc()

# %%
#Variaveis Globais e Locais

x=int(10) #GLOBAL

print(type(x))

def func(a):
  z=1000

  print(z)
  print(a)
  print(x) #Podemos Imprimir uma variavel global dentro de uma função

  resul = z ** a

  return resul

a=11

func(a)


# print(z) -> Não podemos imprimir uma variavel local fora da função

# %%
#Função com retorno

def func(a):
  res=a ** (-1)

  return res

x=func(100)

print(x)

# %% [markdown]
# ## Métodos

# %% [markdown]
# Diferença de Método e Função.
#
# Como o nome já sugere função é um recurso do python onde é possivel realizar determinada funcionalidade a sua notação é nome_da_função(arg)
#
# Já o método é uma função que age sobre um objeto em Python,

# %%
#Diferença entre método e função

lista = [1,2,3,4]

lista.append(10) # MÉTODO

help(lista) #help() é uma função do Python

dir(lista) #dir() é uma função que mostra todos os metodos e atributos de um obj

# %% [markdown]
# ## Lambda

# %%
potencia = lambda x: x**2 #lambda parametro_entrada:instrução

x=potencia(4)
y=potencia(6)

print(x,y)

# %%
divisao = lambda x,y: x/y #Usando dois argumentos

d=divisao(2,9)

print(d)

# %%
def pares():
    lista=[]
    for i in range(1,21):
        if i%2 == 0:
            lista.append(i)
        else:
            print()
            
        
    return lista

print(pares())

# %% [markdown]
# # Arquivos

# %% [markdown]
# ## Primeiros Passos

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Leitura e escrita de arquivos**
#
# A função open() é usada com dois argumentos: open(nome_do_arquivo, modo).
#
# O primeiro argumento é uma string contendo o nome do arquivo. O segundo argumento é outra string, contendo alguns caracteres que descrevem o modo como o arquivo será usado. modo pode ser 'r' quando o arquivo será apenas lido, 'w' para escrever (se o arquivo já existir seu conteúdo prévio será apagado), e 'a' para abrir o arquivo para adição; qualquer escrita será adicionada ao final do arquivo. A opção 'r+' abre o arquivo tanto para leitura como para escrita. O argumento modo é opcional, em caso de omissão será assumido 'r'.

# %%
#r - ler arquivo
#w - escrever no arquivo
#a - abrir o arquivo para adição
#r+ - abrir o arquivo para leitura e escrita

# %%
#Lendo arquivo

arq = open("/content/drive/MyDrive/Colab Notebooks/ARQUIVO/resenha_filme.txt","r") #O argumento modo é opcional, em caso de omissão será assumido 'r'.

help(arq.close) # Para fechar o arquivo

# OBS: APOS TRABALHAR COM ARQUIVOS SEMPRE TEMOS QUE FECHAR.

# %%
# Trabalhando com arquivos com with

with open("/content/drive/MyDrive/Colab Notebooks/ARQUIVO/resenha_filme.txt","r") as f:
  read_data = f.read() 
  print(read_data)
  print(f.tell()) # Conta o numero de Caracteres
  #print(f.seek(0,3)) # Retorna o ponto especifico do Arquivo nesse caso primeira linha, quarta coluna


f.closed # Arquivo já foi fechado automaticamente

# f.readline() -> Ler uma unica linha

# %%
#PARA ESCREVER NO ARQUIVOS TEMOS QUE ABRIR ELE COM O ARQGUMENTO W

arq1 = open("/content/drive/MyDrive/Colab Notebooks/ARQUIVO/resenha_filme.txt","w")

arq1.write("teste \n") #Ele retorna a quantidade de caracteres escrita

arq1.close

# %%
# PARA ABRIR O ARQUIVO TANTO PARA LEITURA QUANTO PARA ESCRITA USAMOS O r+

arq1 = open("/content/drive/MyDrive/Colab Notebooks/ARQUIVO/resenha_filme.txt","r+")

var = arq1.read()
print(var)

arq1.write("askmkdasodkosae \n") #Ele retorna a quantidade de caracteres escrita

print(arq1.read())

arq1.close

# %% [markdown]
# ## Criando arquivos via codigo

# %%
arqnome = input("Digite o nome do arquivo")

arqnome = arqnome + '.txt'

arq = open(arqnome,'w')

arq.write('Arquivo criado com sucesso !!!')

arq.close()

# %%
arq1 = open(arqnome,'r')

print(arq1.read())

# %% [markdown]
# ### Manipulando arquivos csv

# %%
x = open("/content/drive/MyDrive/Colab Notebooks/ML e DS com Python /Secao 10 - Redes neurais artificiais/census.csv","r")

print(x.read())

# %% [markdown]
# ## Trabalhando com Datasets

# %%
nome = input("Digite o nome do arquivo")

filename = nome + '.txt'

arq3= open(filename,"r+")

arq3.write("Arquivo CRIADO")

print(arq3.read())

arq3.close()

# %% [markdown]
# # Módulos e Pacotes

# %% [markdown]
# Um módulo é um arquivo contendo definições e instruções Python. O nome do arquivo é o nome do módulo acrescido do sufixo .py. Dentro de um módulo, o nome do módulo (como uma string) está disponível como o valor da variável global __name__. Por exemplo, use seu editor de texto favorito para criar um arquivo chamado fibo.py no diretório atual com o seguinte conteúdo:

# %%
#Dentro da Pasta ARQUIVOS tem um modulo chamado fibo.py vamos importar ele

import Fibo #Importando módulo

x=Fibo.fib(10)

# %% [markdown]
# ## Pacote Datetime

# %% [markdown]
# https://docs.python.org/pt-br/3/library/datetime.html

# %%
import datetime as dt

agora = dt.datetime.now() #pacote.modulo.função()

print(agora)

t=datetime.time(1,6,20) #criando propria data

print(dir(datetime))

print(t)

# %% [markdown]
# ## Função Map

# %% [markdown]
# https://docs.python.org/pt-br/3/library/functions.html#map

# %%
#FUNCIONAMENTO

def dobro(t):
  return t*2

valores = [10,20,30,30,40,90]

map(dobro,valores) #map(função,lista) | A função map retorna um iterador

print(list(map(dobro,valores)))

# %%
for i in map(dobro,valores):
  print(i)

# %% [markdown]
# ## Função Reduce

# %% [markdown]
# functools.reduce (função, iterável [, inicializador])
# Aplicar a função de dois argumentos cumulativamente aos itens do iterável, da esquerda para a direita, de modo a reduzir o iterável a um único valor. Por exemplo, reduzir (lambda x, y: x + y, [1, 2, 3, 4, 5]) calcula ((((1 + 2) +3) +4) +5). O argumento esquerdo, x, é o valor acumulado e o argumento direito, y, é o valor de atualização do iterável. Se o inicializador opcional estiver presente, ele é colocado antes dos itens do iterável no cálculo e serve como padrão quando o iterável está vazio. Se o inicializador não for fornecido e o iterável contiver apenas um item, o primeiro item será retornado.
#
# Aproximadamente equivalente a:
#
#
# Consulte itertools.accumulate () para um iterador que produz todos os valores intermediários.

# %%
def reduce(function, iterable, initializer=None):
    it = iter(iterable)
    if initializer is None:
        value = next(it)
    else:
        value = initializer
    for element in it:
        value = function(value, element)
    return value

# %% [markdown]
# ## Função Filter

# %% [markdown]
# https://docs.python.org/pt-br/3/library/functions.html#filter

# %%
def verificador(l):
  if l % 2 == 0:
    return True
  else :
    return False

lista = [11,1323123,999,8,6,40,21321,864286]

print(list(filter(verificador,lista)))

# %% [markdown]
# ## List Comprehension

# %%
lst = [x*1.5 for x in range(0,100)]

print(lst)

lst1 = [x for x in range(11) if x % 2 == 0 if x % 4 == 0] # [var,método]

print(lst1)

# %% [markdown]
# ## Função Zip

# %% [markdown]
# https://docs.python.org/pt-br/3/library/functions.html#zip

# %%
lista1= [1,2,3,43,432]
lista2= [12930231,3213,21]

zip(lista1,lista2) # Função Zip retorna um iterador

print(list(zip(lista1,lista2))) # Atenção a lista tem que ter a mesma quantidade de iteradores

# %% [markdown]
# ## Função Enumerate

# %% [markdown]
# https://docs.python.org/pt-br/3/library/functions.html#zip

# %%
lista = [10.132213,321321332,53453454543,43,24424]

enumerate(lista) # Retorna um iterador

print(list(enumerate(lista))) # Retorna uma lista com tuplas onde o primeiro elemento é o indice e o segundo o escopo

# %% [markdown]
# ## Tratamento de Erros e Exceções

# %%
#ERRO 

print('Oi)

# %%
#EXCESSÃO

def div(n1,n2):
  resultado = n1 / n2

div(4,0)

# %% [markdown]
# # Orientação a Objeto

# %% [markdown]
# ## Classes

# %% [markdown]
# https://docs.python.org/pt-br/3/tutorial/classes.html

# %% [markdown]
# Classes proporcionam uma forma de organizar dados e funcionalidades juntos. Criar uma nova classe cria um novo “tipo” de objeto, permitindo que novas “instâncias” desse tipo sejam produzidas. Cada instância da classe pode ter atributos anexados a ela, para manter seu estado. Instâncias da classe também podem ter métodos (definidos pela classe) para modificar seu estado.

# %% [markdown]
# ### Criando Classe

# %% [markdown]
# Objetos classe suportam dois tipos de operações: referências a atributos e instanciação.
#
# Referências a atributos de classe utilizam a sintaxe padrão utilizada para quaisquer referências a atributos em Python: obj.nome. Nomes de atributos válidos são todos os nomes presentes dentro do espaço de nomes da classe, quando o objeto classe foi criado. Portanto, se a definição de classe tem esta forma:

# %%
class Myclass:
    """A simple example class"""
    i = 12345

    def f(self):
        return 'hello world'

print(Myclass.i) #referências a atributos
print(Myclass.f) #referências a atributos
print(Myclass.__doc__) #referências a Docstring da classe

x=Myclass() #instanciando uma classe

print(f'N={x.i}, retornando {x.f()}')

# %% [markdown]
# O método __init__(), o processo de instanciação automaticamente invoca __init__() sobre a instância recém criada. Em nosso exemplo, uma nova instância já inicializada pode ser obtida desta maneira:

# %%
class filme():
  def __init__(self):
    self.nome="300"
  
  def imprimir(self):
    print(nome)

x=filme()
print(x.nome)
print(x.imprimir())

# %%
class Dog:

    kind = 'canine'         # class variable shared by all instances

    def __init__(self, name):
        self.name = name    # instance variable unique to each instance

d = Dog('Fido')
e = Dog('Buddy')

print(d.kind)                  # shared by all dogs

print(e.kind)                  # shared by all dogs

print(d.name)                  # unique to d

print(e.name)                  # unique to e

# %%
#Classe com argumento

class teste:
  def __init__(self,arg1,arg2):
    self.x = arg1
    self.y = arg2

p1 = teste(1.90,1.88)

print(p1.x)

# %%
#Criando classe sem metodos e atributos (CLASSE VAZIA)

class Carro():
  pass

vw = Carro()
print(type(vw))

# %%
#Classes de Objetos com conteudos pré determinados

class Livro(): #class nome_da_classe(arg):

  def __init__(self):  #__init__ -> método do construtor 
    self.titulo ="Livro Generico" 
    self.autor ="Autor Generico"
    self.editora ="Editora Generica"

  def imprime(self):
    print("O livro foi criado")


livro_1= Livro()

print(livro_1.titulo) # livro_1.atributo
print(livro_1.imprime()) #livro_1.metodo

# %%
#Classes de Objetos com conteudos personalizados

class Livro(): #class nome_da_classe(arg):

  def __init__(self,titulo,autor,editora):  #__init__ -> método do construtor 
    self.titulo = titulo
    self.autor = autor
    self.editora = editora
    
  def imprime(self,titulo):
    print("O livro %s foi criado" %(titulo))

livro_2 = Livro("Arte da Guerra", "SunTzu","Chi Xin")

print(livro_2.imprime("Sapiens"))

# %%
class carro:
  def __init__(self,marca,modelo):
    self.marca=marca
    self.modelo=modelo

  def imprime(self,marca,modelo):
    return f"Parabens você comprou um {marca}-{modelo}"

  def xi(self):
    print( f'Voce tinha um {self.marca}-{self.modelo}')

carro1 =carro("VW","Polo") # 1

print(carro1.imprime('GM','Onix'))

carro1.xi() # 1

# %%
class calc():
  def __init__(self,x,y):
    self.lado1 = x # ou self.x = x
    self.lado2=y # ou self.y = y

  def setArea(self,x,y):
    area = x * y
    print("setado")

  def getArea(self,x,y):
    return x * y


instancia = calc(10,20)

print(instancia.getArea(10,20))

# %% [markdown]
# ###  Herança

# %%
class Animal(): #Super classe
  def __init__(self):
    print("Animal Criado")

  def acao(self):
    print("Comer, Reproduzir,Morrer")

  def carac(self):
    print("Animalia")

  def iden(self):
    print("10")

class cao(Animal): #Sub Classe
  def __init__(self):
    Animal.__init__(self)
    print("cao criado")

  def iden(self):
    print("11")

tst = cao() #Ele mostra todos os metodos inclusive os metodos herdados

print("---"*10)

tst.carac() #Ele mostra a herança da classe pai

tst.iden() #Ele mostra o atributo da classe mais interna

# %% [markdown]
# ### Métodos Especiais

# %%
class Livro():
  def __init__(self,nome,autor,pag): #metodo especial
    self.nome=nome
    self.autor=autor
    self.pag=pag
    print("Livro Criado")

  def __str__(self): #metodo especial
    return "O livro %s do autor %s na pagina %i" %(self.nome,self.autor,self.pag)

  def __len__(self): #metodo especial
    return self.pag

  def lenn(self): #metodo normal
    print(f"Pagina {self.pag}")

livro1 = Livro("Arte da Guerra","Sun Tzu",112)

print(livro1) # A seguinte mensagem foi impressa por conta do metodo especial __str__
str(livro1) # Podemos fazer a seguinte chamada


print("---"*10)

len(livro1) #Chamada do metodo especial __len__

print(livro1.lenn())
